# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from skin.agent import firmAgent, networkAgent
from skin.model import skinModel
from mesa.batchrunner import BatchRunner

# %%
model = skinModel(nFirms = 500,
                  nProducts = 100,
                  nInputs = 4, 
                  n_big_firms_percent = 10, 
                  reward_to_trigger_start_up = 1200, 
                  attractiveness_threshold = 0.3,
                  partnership_strategy = 'conservative', 
                  success_threshold = 1000, 
                  in_out_product_percent = 10, 
                  initial_capital = 20000, 
                  Partnering = True,
                  Networking = False,
                  Start_ups = True,
                  Adj_expertise = True,
                  Adj_price = True,
                  Incr_research = True,
                  Rad_research = True,
                  width = 100,
                  height = 100,
                  max_iters = 100,
                  batch_mode = False
                 )
model.run_model()

# %%
model_out = model.dc.get_model_vars_dataframe()

# %%
model_out
# Out:
#       Capital  In partnership  In network  Firms  Networks  Successes  \
# 0    4.399632        7.355865         0.0    503         0   2.012072
# 1    4.396643       10.869565         0.0    506         0   1.234568
# 2    4.393880       15.324165         0.0    509         0   1.204819
# 3    4.394281       19.726562         0.0    512         0   3.600000
# 4    4.391242       22.524272         0.0    515         0   0.978474
# ..        ...             ...         ...    ...       ...        ...
# 96   5.309775       70.686767         0.0    597         0  43.074324
# 97   5.316104       70.637584         0.0    596         0  43.455497
# 98   5.325827       70.637584         0.0    596         0  44.087838
# 99   5.333993       71.140940         0.0    596         0  45.438596
# 100  5.343126       71.812081         0.0    596         0  42.203390
#
#      Start-ups  Firms selling  Firms trading        Sales       Profit  \
# ...

# %%
population = model_out[['Firms', 'Networks']]

# %%
ax = population.plot()
ax.set_title('Population Over Time')
ax.set_xlabel('Step')
ax.set_ylabel('Number of Firms')
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))

# %%
collaboration = model_out[['In partnership', 'In network']]

# %%
ax =collaboration.plot()
ax.set_title('Collaboration Over Time')
ax.set_xlabel('Step')
ax.set_ylabel('%')
#_ = ax.legend(bbox_to_anchor=(1.35, 1.025))
# Out:
# Text(0, 0.5, '%')

# %%
dynamics = model_out[['Successes', 'Start-ups']]

# %%
ax =dynamics.plot()
ax.set_title('Dynamics Over Time')
ax.set_xlabel('Step')
ax.set_ylabel('% of firms')
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))

# %%
transactions = model_out[['Firms selling', 'Firms trading']]

# %%
ax =transactions.plot()
ax.set_title('Transactions Over Time')
ax.set_xlabel('Step')
ax.set_ylabel('%')
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))

# %%
sales = model_out[['Sales', 'Profit']]

# %%
ax =sales.plot()
ax.set_title('Sales Over Time')
ax.set_xlabel('Step')
ax.set_ylabel('mean value per firm')
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))

# %%
capital = model_out['Capital']

# %%
ax = capital.plot()
ax.set_title('Capital Over Time')
ax.set_xlabel('Step')
ax.set_ylabel('Capital')
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))

# %%
rate_of_radical_research = model_out['Rate of radical research']

# %%
ax = rate_of_radical_research.plot()
ax.set_title('Rate of radical research Histogram')
ax.set_xlabel('')
ax.set_ylabel('')
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))

# %%
agent_out = model.dc.get_agent_vars_dataframe()

# %%
agent_out
# Out:
#                x   y                                           Partners  \
# Step AgentID
# 1    0        47  68  [2, 1, 1, 1, 2, 1, 1, 1, 1, 1, 1, 2, 1, 1, 1, ...
#      1        25  67  [2, 1, 1, 1, 2, 1, 1, 1, 1, 1, 1, 2, 1, 1, 1, ...
#      2        83  23  [2, 1, 1, 1, 2, 1, 1, 1, 1, 1, 1, 2, 1, 1, 1, ...
#      3        92  57  [2, 1, 1, 1, 2, 1, 1, 1, 1, 1, 1, 2, 1, 1, 1, ...
#      4        14  23  [2, 1, 1, 1, 2, 1, 1, 1, 1, 1, 1, 2, 1, 1, 1, ...
# ...           ..  ..                                                ...
# 101  622      45  48  [3, 2, 1, 1, 2, 3, 1, 2, 1, 1, 2, 5, 1, 1, 3, ...
#      606      56  20  [3, 2, 1, 1, 2, 3, 1, 2, 1, 1, 2, 5, 1, 1, 3, ...
#      604      49  26  [3, 2, 1, 1, 2, 3, 1, 2, 1, 1, 2, 5, 1, 1, 3, ...
#      602      36  24  [3, 2, 1, 1, 2, 3, 1, 2, 1, 1, 2, 5, 1, 1, 3, ...
#      599      98  47  [3, 2, 1, 1, 2, 3, 1, 2, 1, 1, 2, 5, 1, 1, 3, ...
#
#                                                Age distribution  \
# Step AgentID
# ...

# %%
artefacts = agent_out[['Product', 'Inputs']][101]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 101
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-0387a3c8fc72> in <module>
# ...

# %%
ax = artefacts.plot.bar(stacked=True)
ax.set_title('Artefacts')
ax.set_xlabel('')
ax.set_ylabel('')
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-53219185ca07> in <module>
# ----> 1 ax = artefacts.plot.bar(stacked=True)
#       2 ax.set_title('Artefacts')
#       3 ax.set_xlabel('')
#       4 ax.set_ylabel('')
#       5 _ = ax.legend(bbox_to_anchor=(1.35, 1.025))
#
# NameError: name 'artefacts' is not defined

# %%
import pandas as pd
partners = agent_out['Partners'][300]
partners_pd=pd.DataFrame(partners)

# %%
ax = partners_pd.plot.hist()
ax.set_title('Partners Histogram')
ax.set_xlabel('Number')
ax.set_ylabel('Frequency')
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))

# %%
age_distribution = agent_out['Age distribution'][300]

# %%
ax = age_distribution.plot.hist()
ax.set_title('Age distribution')
ax.set_xlabel('Age')
ax.set_ylabel('N')
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-84895b84901e> in <module>
# ----> 1 ax = age_distribution.plot.hist()
#       2 ax.set_title('Age distribution')
#       3 ax.set_xlabel('Age')
#       4 ax.set_ylabel('N')
#       5 _ = ax.legend(bbox_to_anchor=(1.35, 1.025))
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/plotting/_core.py in hist(self, by, bins, **kwargs)
#    1123             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1124         """
# -> 1125         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1126
#    1127     def kde(self, bw_method=None, ind=None, **kwargs):
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
# ...

# %%
size_distribution = agent_out['Size distribution'][300]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-4f8de87cac72> in <module>
# ----> 1 size_distribution = agent_out['Size distribution'][300].age
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'age'

# %%
ax = size_distribution.plot.hist()
ax.set_title('Size distribution')
ax.set_xlabel('')
ax.set_ylabel('')
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-8b08e1790e80> in <module>
# ----> 1 ax = size_distribution.plot.hist()
#       2 ax.set_title('Size distribution')
#       3 ax.set_xlabel('')
#       4 ax.set_ylabel('')
#       5 _ = ax.legend(bbox_to_anchor=(1.35, 1.025))
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/plotting/_core.py in hist(self, by, bins, **kwargs)
#    1123             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1124         """
# -> 1125         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1126
#    1127     def kde(self, bw_method=None, ind=None, **kwargs):
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
# ...
